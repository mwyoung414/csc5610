# %%
import pandas as pd
import polars as pl
import numpy as np
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
used_cars_pl_df = pl.read_csv('used_car_sale_prices.csv')

# %%
profile = ProfileReport(used_cars_pl_df.to_pandas(), title="Used Cars Data Profile", explorative=True)
profile.to_file("used_cars_data_profile.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
used_cars_pl_df.columns
# Out:
# ['Id',
#  'Model',
#  'Price',
#  'Age_08_04',
#  'KM',
#  'Fuel_Type',
#  'HP',
#  'Color',
#  'Automatic',
#  'CC',
#  'Doors',
#  'Cylinders',
#  'Gears',
#  'Quarterly_Tax',
#  'Weight',
#  'Mfr_Guarantee',
#  'BOVAG_Guarantee',
#  'Guarantee_Period',
#  'ABS',
#  'Airbag_1',
#  'Airbag_2',
#  'Airco',
#  'Automatic_airco',
#  'Boardcomputer',
#  'CD_Player',
#  'Central_Lock',
#  'Powered_Windows',
#  'Power_Steering',
#  'Radio',
#  'Mistlamps',
#  'Sport_Model',
#  'Backseat_Divider',
#  'Metallic_Rim',
#  'Radio_cassette',
#  'Parking_Assistant',
#  'Tow_Bar',
#  'Mfg_Date']

# %% [markdown]
# - ID - Removed
# - KM - multipled by 0.621371 and appeneded as 'Miles' feature and dropped 'KM' feature
# - Automatic - two distinct values and 96% of the values are No
# - Cylinders (All are 4 Cylinders with some fields of -1 (unknown values))
# - Parking_Assisstant - two distinct values and 99% of the values are NO
# - Doors (Can be Inferred from the Model)
# - Gears (highly imbalanced)

# %% [markdown]
# #### Find Correlations
#
# Look at Airbag_1
# Look at Airbag_2
# Automatic_airco
# Power_Steering

# %%
used_cars_pl_df.drop(['Id','Color' 'Automatic', 'Parking_Assistant', 'Powering_Steering', 'Automatic_airco', 'Airbag_1', 'Cylinders'], inplace=True)

# %%
used_cars["Miles"] = used_cars['KM'] * 0.621371
used_cars.drop(columns=['KM'], inplace=True)
